# %%
import random

# %%
numbers="1234567890"
lower="abcdefghijklmnopqrstuvwxyz"
upper="ABCDEFGHIJKLMOPQRSTUVWXYZ"
symbol="!@#$%^&*()[]{}"

length=16

all=numbers+lower+upper+symbol

password = "".join(random.choice(all) for i in range(length))

print("password:",password)
# Out:
# password: SD*kix*[5}](p4xi
